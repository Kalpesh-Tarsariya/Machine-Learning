# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\A\Downloads\COVID.csv")
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0                 0.1           0.9                     3.0
# 1                 NaN           NaN                     NaN
# ...

# %%
df.isnull().sum()
# Out:
# Outcome                              0
# Week End                             0
# Age Group                            0
# Unvaccinated Rate                    0
# Vaccinated Rate                    327
# Boosted Rate                      1224
# Crude Vaccinated Ratio            1433
# Crude Boosted Ratio               1992
# Age-Adjusted Unvaccinated Rate    3336
# Age-Adjusted Vaccinated Rate      3336
# Age-Adjusted Boosted Rate         3423
# Age-Adjusted Vaccinated Ratio     3373
# Age-Adjusted Boosted Ratio        3441
# Population Unvaccinated              0
# Population Vaccinated              540
# Population Boosted                1224
# Outcome Unvaccinated                 0
# Outcome Vaccinated                 327
# Outcome Boosted                   1224
# Age Group Min                        0
# Age Group Max                        0
# dtype: int64

# %%
vacc_mean = df["Vaccinated Rate"].mean()
df["Vaccinated Rate"] = df["Vaccinated Rate"].fillna(vacc_mean)
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0            0.100000           0.9                     3.0
# 1           42.439521           NaN                     NaN
# ...

# %%
Boost_mean = df["Boosted Rate"].mean()
df["Boosted Rate"] = df["Boosted Rate"].fillna(Boost_mean)
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0            0.100000      0.900000                     3.0
# 1           42.439521     48.649783                     NaN
# ...

# %%
Crude_vacc_mean = df["Crude Vaccinated Ratio"].mean()
df["Crude Vaccinated Ratio"] = df["Crude Vaccinated Ratio"].fillna(Crude_vacc_mean)
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0            0.100000      0.900000                 3.00000
# 1           42.439521     48.649783                 4.54694
# ...

# %%
Crude_Boost_mean = df["Crude Boosted Ratio"].mean()
df["Crude Boosted Ratio"] = df["Crude Boosted Ratio"].fillna(Crude_Boost_mean)
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0            0.100000      0.900000                 3.00000
# 1           42.439521     48.649783                 4.54694
# ...

# %%
age_unvacc_mean = df["Age-Adjusted Unvaccinated Rate"].mean()
df["Age-Adjusted Unvaccinated Rate"] = df["Age-Adjusted Unvaccinated Rate"].fillna(age_unvacc_mean)
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0            0.100000      0.900000                 3.00000
# 1           42.439521     48.649783                 4.54694
# ...

# %%
age_vacc_mean = df["Age-Adjusted Vaccinated Rate"].mean()
df["Age-Adjusted Vaccinated Rate"] = df["Age-Adjusted Vaccinated Rate"].fillna(age_vacc_mean)
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0            0.100000      0.900000                 3.00000
# 1           42.439521     48.649783                 4.54694
# ...

# %%
age_vaccratio_mean = df["Age-Adjusted Vaccinated Ratio"].mean()
df["Age-Adjusted Vaccinated Ratio"] = df["Age-Adjusted Vaccinated Ratio"].fillna(age_vaccratio_mean)
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0            0.100000      0.900000                 3.00000
# 1           42.439521     48.649783                 4.54694
# ...

# %%
age_boost_mean = df["Age-Adjusted Boosted Ratio"].mean()
df["Age-Adjusted Boosted Ratio"] = df["Age-Adjusted Boosted Ratio"].fillna(age_boost_mean)
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0            0.100000      0.900000                 3.00000
# 1           42.439521     48.649783                 4.54694
# ...

# %%
pop_vacc_mean = df["Population Vaccinated"].mean()
df["Population Vaccinated"] = df["Population Vaccinated"].fillna(pop_vacc_mean)
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0            0.100000      0.900000                 3.00000
# 1           42.439521     48.649783                 4.54694
# ...

# %%
pop_boost_mean = df["Population Boosted"].mean()
df["Population Boosted"] = df["Population Boosted"].fillna(pop_boost_mean)
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0            0.100000      0.900000                 3.00000
# 1           42.439521     48.649783                 4.54694
# ...

# %%
out_vacc_mean = df["Outcome Vaccinated"].mean()
df["Outcome Vaccinated"] = df["Outcome Vaccinated"].fillna(out_vacc_mean)
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0            0.100000      0.900000                 3.00000
# 1           42.439521     48.649783                 4.54694
# ...

# %%
out_boost_mean = df["Outcome Boosted"].mean()
df["Outcome Boosted"] = df["Outcome Boosted"].fillna(out_boost_mean)
df
# Out:
#                Outcome    Week End Age Group  Unvaccinated Rate  \
# 0               Deaths  10/01/2022       All                0.3
# 1               Deaths  07/09/2022       0-4                0.0
# 2                Cases  11/12/2022       0-4               82.4
# 3     Hospitalizations  08/13/2022       0-4                7.4
# 4                Cases  02/26/2022       0-4               54.1
# ...                ...         ...       ...                ...
# 3748            Deaths  11/13/2021     65-79                8.7
# 3749             Cases  09/30/2023     18-29               51.0
# 3750            Deaths  10/09/2021       80+               16.4
# 3751            Deaths  09/25/2021       80+               19.4
# 3752             Cases  10/16/2021       80+               33.0
#
#       Vaccinated Rate  Boosted Rate  Crude Vaccinated Ratio  \
# 0            0.100000      0.900000                 3.00000
# 1           42.439521     48.649783                 4.54694
# ...
